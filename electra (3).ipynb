# %% [markdown]
# [GitHub](https://github.com/elsanns/xai-nlp-notebooks/blob/master/electra_fine_tune_interpret_captum_ig.ipynb)
# # Fine-tuning Electra on SST-2 and interpreting with Integrated Gradients
#
# ---

# %% [markdown]
# This notebook contains an example of [fine-tuning](https://huggingface.co/transformers/training.html) an [Electra](https://huggingface.co/transformers/model_doc/electra.html) model on the [GLUE SST-2](https://nlp.stanford.edu/sentiment/index.html) dataset. After fine-tuning, the [Integrated Gradients](https://arxiv.org/pdf/1703.01365.pdf) **interpretability** method is applied to compute tokens' attributions for each target class.
# * We will instantiate a pre-trained Electra model from the [Transformers](https://huggingface.co/transformers/) library.
# * The data is downloaded from the [nlp](https://huggingface.co/nlp/) library. The input text is tokenized with [ElectraTokenizerFast](https://huggingface.co/transformers/model_doc/electra.html#electratokenizerfast) tokenizer backed by HF [tokenizers](https://huggingface.co/transformers/main_classes/tokenizer.html) library.
# * **Fine-tuning** for sentiment analysis is handled by the [Trainer](https://huggingface.co/transformers/main_classes/trainer.html) class.
# * After fine-tuning, the [Integrated Gradients](https://captum.ai/api/integrated_gradients.html) interpretability algorithm will assign importance scores to
# input tokens. We will use a **PyTorch** implementation from the [Captum](https://captum.ai/) library.
#   - The algorithm requires providing a reference sample (a baseline) since importance attribution is performed based on the model's output, as inputs change from reference values to the actual sample.
#   - The Integrated Gradients method satisfies the **completeness** property. We will look at the sum of attributions for a sample and show that the sum approximates (explains) prediction's shift from the baseline value.
# * The final sections of the notebook contain a color-coded **visualization** of attribution results made with *captum.attr.visualization* library.
#
# The notebook is based on the [Hugging Face documentation](https://huggingface.co/) and the implementation of Integrated Gradients attribution methods is adapted from the Captum.ai
# [Interpreting BERT Models (Part 1)](https://captum.ai/tutorials/Bert_SQUAD_Interpret).

# %% [markdown]
# ## Installation & imports
#
# ---

# %%
# !pip install transformers
# !pip install pyarrow
# !pip install nlp
# !pip install datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in ./.local/lib/python3.8/site-packages (4.27.3)
# Requirement already satisfied: tqdm>=4.27 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in ./.local/lib/python3.8/site-packages (from transformers) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from transformers) (20.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in ./.local/lib/python3.8/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: numpy>=1.17 in ./.local/lib/python3.8/site-packages (from transformers) (1.24.2)
# Requirement already satisfied: requests in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from transformers) (2.22.0)
# Requirement already satisfied: regex!=2019.12.17 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from transformers) (2020.11.13)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in ./.local/lib/python3.8/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: pyyaml>=5.1 in ./.local/lib/python3.8/site-packages (from transformers) (6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: six in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from packaging>=20.0->transformers) (1.14.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (3.7.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<2.9,>=2.5 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from requests->transformers) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./.local/lib/python3.8/site-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from requests->transformers) (3.0.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyarrow in ./.local/lib/python3.8/site-packages (11.0.0)
# Requirement already satisfied: numpy>=1.16.6 in ./.local/lib/python3.8/site-packages (from pyarrow) (1.24.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nlp in ./.local/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: numpy in ./.local/lib/python3.8/site-packages (from nlp) (1.24.2)
# Requirement already satisfied: pyarrow>=0.16.0 in ./.local/lib/python3.8/site-packages (from nlp) (11.0.0)
# Requirement already satisfied: pandas in ./.local/lib/python3.8/site-packages (from nlp) (1.5.3)
# Requirement already satisfied: xxhash in ./.local/lib/python3.8/site-packages (from nlp) (3.2.0)
# Requirement already satisfied: dill in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from nlp) (0.3.5.1)
# Requirement already satisfied: tqdm>=4.27 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from nlp) (4.64.1)
# Requirement already satisfied: requests>=2.19.0 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from nlp) (2.22.0)
# Requirement already satisfied: filelock in ./.local/lib/python3.8/site-packages (from nlp) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from pandas->nlp) (2.8.1)
# Requirement already satisfied: pytz>=2020.1 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from pandas->nlp) (2020.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from requests>=2.19.0->nlp) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from requests>=2.19.0->nlp) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from requests>=2.19.0->nlp) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./.local/lib/python3.8/site-packages (from requests>=2.19.0->nlp) (1.25.11)
# Requirement already satisfied: six>=1.5 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->nlp) (1.14.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in ./.local/lib/python3.8/site-packages (2.10.1)
# Requirement already satisfied: aiohttp in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from datasets) (3.8.1)
# Requirement already satisfied: pyarrow>=6.0.0 in ./.local/lib/python3.8/site-packages (from datasets) (11.0.0)
# Requirement already satisfied: responses<0.19 in ./.local/lib/python3.8/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: pandas in ./.local/lib/python3.8/site-packages (from datasets) (1.5.3)
# Requirement already satisfied: tqdm>=4.62.1 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from datasets) (4.64.1)
# Requirement already satisfied: packaging in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from datasets) (20.4)
# Requirement already satisfied: numpy>=1.17 in ./.local/lib/python3.8/site-packages (from datasets) (1.24.2)
# Requirement already satisfied: multiprocess in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from datasets) (0.70.13)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in ./.local/lib/python3.8/site-packages (from datasets) (2023.3.0)
# Requirement already satisfied: xxhash in ./.local/lib/python3.8/site-packages (from datasets) (3.2.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.local/lib/python3.8/site-packages (from datasets) (6.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in ./.local/lib/python3.8/site-packages (from datasets) (0.13.3)
# Requirement already satisfied: requests>=2.19.0 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from datasets) (2.22.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: aiosignal>=1.1.2 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from aiohttp->datasets) (19.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: urllib3>=1.25.10 in ./.local/lib/python3.8/site-packages (from responses<0.19->datasets) (1.25.11)
# Requirement already satisfied: python-dateutil>=2.8.1 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: pytz>=2020.1 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from pandas->datasets) (2020.4)
# Requirement already satisfied: six in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from packaging->datasets) (1.14.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.7.4.3)
# Requirement already satisfied: filelock in ./.local/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.10.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /apps/jupyterhub/1.1.0/lib/python3.8/site-packages (from requests>=2.19.0->datasets) (2021.10.8)

# %%
from typing import Dict

import matplotlib.pyplot as plt
import nlp
import numpy as np
import pandas as pd
import torch
import transformers
from torch.utils.data import Dataset
from transformers import (ElectraForSequenceClassification,
                          ElectraTokenizerFast, EvalPrediction, InputFeatures,
                          Trainer, TrainingArguments, glue_compute_metrics)

from datasets import load_dataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import (precision_recall_fscore_support, accuracy_score)

transformers.__version__
# Out:
# '4.27.3'

# %% [markdown]
# ## Model
#
# ---

# %% [markdown]
# Sentiment analysis is a classification task that requires assigning a label to an entire sentence (sequence). We will use a PyTorch implementation of [`ElectraForSequenceClassification`](https://huggingface.co/transformers/model_doc/electra.html#electraforsequenceclassification) from the Hugging Face library. A matching tokenizer implemented in the [`ElectraTokenizerFast`](https://huggingface.co/transformers/model_doc/electra.html#electratokenizerfast) class will handle tokenization.

# %%
model = ElectraForSequenceClassification.from_pretrained(
    "google/electra-small-discriminator", num_labels=2)

tokenizer = ElectraTokenizerFast.from_pretrained(
    "google/electra-small-discriminator", do_lower_case=True)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/54.2M [00:00<?, ?B/s]
# Some weights of the model checkpoint at google/electra-small-discriminator were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight', 'discriminator_predictions.dense_prediction.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at google/electra-small-discriminator and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %% [markdown]
# ## Data
#
# ---

# %% [markdown]
# **Download**
#
# Let's now download the SST-2 dataset from the nlp library and take a brief look at it. It contains short movie reviews labelled for sentiment: 0 for negative and 1 for a positive review. The data is split into training, validation and test set. The labels for the test set are kept undisclosed.

# %%
# Load the SST2 dataset from the nlp library
dataset = load_dataset('ucberkeley-dlab/measuring-hate-speech')['train']
dataset = pd.DataFrame(dataset)

# Preprocess the data by removing unnecessary columns
dataset = dataset[['text', 'hate_speech_score']]
dataset['label'] = dataset['hate_speech_score'].apply(lambda x: 1 if x >= 0 else 0)
dataset = dataset[['text', 'label']]

train_data, test_data = train_test_split(dataset, test_size=0.2, random_state=42)

# Look at the labels
print("Training set labels: {}".format(set(train_data["label"])))
print("Test set labels: {}".format(set(test_data["label"])))

# Explore the dataset
df = pd.DataFrame({"sentence": train_data["text"],
                   "label": train_data["label"]})
pd.options.display.max_colwidth = 0
df.head()
# Out:
# Found cached dataset parquet (/home/r.bhairagond/.cache/huggingface/datasets/ucberkeley-dlab___parquet/ucberkeley-dlab--measuring-hate-speech-c32713cabe528196/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/1 [00:00<?, ?it/s]
# Training set labels: {0, 1}
# Test set labels: {0, 1}
#                                                                                                                                                                                                                                                                                                           sentence  \
# 104822  GET RID OF THOSE FUCKING MUSLIMS! the nasty ones that won't assimilate, rape women, beat children, threaten democracy, plan terror attacks, assault innocent secular people and force their disgusting religion on everyone else by way of violence. Assimilate OR GET THE FUCK OUT OR BE PREPARED TO DIE!
# 71077   when addressing a crowd of white women @RepBarbaraLee says "we have the resources" to pay teachers more if we cut the $717B defense budget. when will #ADOS get this kind of advocacy @OfficialCBC ? why can't we find this same creativity to fund reparations? URL
# 128973  I love that you enjoy being trans.
# 87800   Super sexy redhead babes @bbwjulieginger and @ElizaAllure show just how sexy they can be in this hot lesbian scene now at URL URL
# 117885  Learn the fucking language you fucking useless immigrant.
#
#         label
# 104822  1
# 71077   0
# 128973  0
# 87800   0
# 117885  1

# %% [markdown]
# **Create dataset**
#
# We will now create a custom [map-style PyTorch dataset](https://pytorch.org/docs/stable/data.html#map-style-datasets) to serve model's key-value parameters in a seamless manner.
#
# The `TrainerDataset` class is derived from `torch.utils.data.Dataset`. The overridden `__getitem__` method yields an instance of the `InputFeatures` class.
#
# Conversion to torch tensors and placing on cuda/cpu is handled by the `trainer` object used for fine-tuning.

# %%
class TrainerDataset(Dataset):
    def __init__(self, inputs, targets, tokenizer):
        self.inputs = inputs
        self.targets = targets
        self.tokenizer = tokenizer

        # Tokenize the input
        self.tokenized_inputs = tokenizer(inputs, padding=True)   

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return InputFeatures(
            input_ids=self.tokenized_inputs['input_ids'][idx],
            token_type_ids=self.tokenized_inputs['token_type_ids'][idx],
            attention_mask=self.tokenized_inputs['attention_mask'][idx],
            label=self.targets[idx])

# %% [markdown]
# We need to create the training and validation datasets. As GLUE SST-2 dataset does not disclose labels for the test set, so we will be using validation data for testing.

# %%
train_dataset = TrainerDataset(train_data["text"].tolist(),
                               train_data["label"].tolist(), tokenizer)
eval_dataset = TrainerDataset(test_data["text"].tolist(),
                              test_data["label"].tolist(), tokenizer)

# %% [markdown]
# ## Fine-tuning
#
# ---

# %% [markdown]
# Fine-tuning with a `Trainer` class instance requires setting training arguments and creating a `trainer` object. The model, as well as training and validation datasets, are passed to the trainer's constructor, along with training arguments. We will pass one more parameter, the `compute_metrics` function, to have the `trainer` calculate the *Accuracy* metric after fine-tuning. The `Trainer` class takes care of conversion to tensor format and placement on a cpu/gpu device.

# %% [markdown]
# ### Set parameters

# %% [markdown]
# Training parameters have been taken from the [Electra Github](https://github.com/google-research/electra/blob/master/configure_finetuning.py) repository or are default values.

# %%
# Set seed for reproducibility
np.random.seed(123)
torch.manual_seed(123)

training_args = TrainingArguments(
    output_dir="./models/model_electra",
    num_train_epochs=3,  # 1 (1 epoch gives slightly lower accuracy)
    overwrite_output_dir=True,
    do_train=True,
    do_eval=True,
    per_device_train_batch_size=32,
    evaluation_strategy='epoch',     
    dataloader_drop_last=True,  # Make sure all batches are of equal size
)


def compute_metrics(p: EvalPrediction) -> Dict:
    preds = np.argmax(p.predictions, axis=1)
    precision, recall, f1, _ = precision_recall_fscore_support(p.label_ids, preds, average='weighted')
    acc = accuracy_score(p.label_ids, preds)
    return {
        "accuracy": acc,
        "precision": precision,
        "recall": recall,
        "f1_score": f1
    }


# Instantiate the Trainer class
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    compute_metrics=compute_metrics)

# %% [markdown]
# ### Run fine-tuning

# %% [markdown]
# Run the `train` method of the `trainer` object to fine-tune the model on the SST-2 dataset.

# %%
trainer.train()
# Out:
# /home/r.bhairagond/.local/lib/python3.8/site-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='10164' max='10164' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10164/10164 5:20:32, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.043400</td>
#       <td>0.292543</td>
#       <td>0.950465</td>
#       <td>0.950479</td>
#       <td>0.950465</td>
#       <td>0.950422</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.064800</td>
#       <td>0.231790</td>
#       <td>0.954596</td>
#       <td>0.955164</td>
#       <td>0.954596</td>
#       <td>0.954471</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.059100</td>
#       <td>0.200842</td>
#       <td>0.963559</td>
#       <td>0.963551</td>
#       <td>0.963559</td>
#       <td>0.963552</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=10164, training_loss=0.05859436345166083, metrics={'train_runtime': 19234.7462, 'train_samples_per_second': 16.914, 'train_steps_per_second': 0.528, 'total_flos': 3569565926158848.0, 'train_loss': 0.05859436345166083, 'epoch': 3.0})

# %% [markdown]
# ### Evaluate

# %% [markdown]
# The metric used for evaluation of the Stanford Sentiment Treebank (SST) data is *Accuracy*. The result is returned by the `Trainer` class object used for fine-tuning.

# %%
model_result = trainer.evaluate()
for key, value in model_result.items():
    print("{}: {}".format(key, value))
# Out:
# eval_loss: 0.20084160566329956
# eval_accuracy: 0.9635585718501033
# eval_precision: 0.963550516987135
# eval_recall: 0.9635585718501033
# eval_f1_score: 0.9635524213192739
# eval_runtime: 656.4294
# eval_samples_per_second: 41.302
# eval_steps_per_second: 5.163
# epoch: 3.0
